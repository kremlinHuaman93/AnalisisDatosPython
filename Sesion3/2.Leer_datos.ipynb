# %%
pip install "pymongo[srv]"

# %%
pip install sqlalchemy

# %%
pip install mysqlclient

# %%
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd

# %%
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db")
conn = engine.connect()

# %%
customers_df = pd.read_sql_query("select * from customers", con=conn)
customers_df
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 0                1        Richard      Hernandez      XXXXXXXXX
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 3                4           Mary          Jones      XXXXXXXXX
# 4                5         Robert         Hudson      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 0             XXXXXXXXX          6303 Heather Plaza   Brownsville
# ...

# %%
customers_df_2 = pd.read_sql_table('categories', engine)
customers_df_2
# Out:
#     category_id  category_department_id         category_name
# 0             1                       2              Football
# 1             2                       2                Soccer
# 2             3                       2   Baseball & Softball
# 3             4                       2            Basketball
# 4             5                       2              Lacrosse
# 5             6                       2      Tennis & Racquet
# 6             7                       2                Hockey
# 7             8                       2           More Sports
# 8             9                       3      Cardio Equipment
# 9            10                       3     Strength Training
# 10           11                       3   Fitness Accessories
# 11           12                       3          Boxing & MMA
# 12           13                       3           Electronics
# 13           14                       3        Yoga & Pilates
# ...

# %%
from pymongo import MongoClient

conn_string = "mongodb+srv://m001-student:bYEtUox9zCt3rK8n@sandbox.okkbl.mongodb.net/?retryWrites=true&w=majority&appName=Sandbox"
client = MongoClient(conn_string)

client['sample_airbnb']
# Out:
# Database(MongoClient(host=['sandbox-shard-00-00.okkbl.mongodb.net:27017', 'sandbox-shard-00-01.okkbl.mongodb.net:27017', 'sandbox-shard-00-02.okkbl.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Sandbox', authsource='admin', replicaset='atlas-7v4uny-shard-0', tls=True), 'sample_airbnb')

# %%
coleccion = client['sample_airbnb']['listingsAndReviews']
cursor_mongo = coleccion.find({'maximum_nights': "30"})

df = pd.DataFrame(cursor_mongo)
df
# Out:
#           _id                            listing_url  \
# 0    10542174  https://www.airbnb.com/rooms/10542174
# 1    10006546  https://www.airbnb.com/rooms/10006546
# 2    10280433  https://www.airbnb.com/rooms/10280433
# 3      102995    https://www.airbnb.com/rooms/102995
# 4    10220130  https://www.airbnb.com/rooms/10220130
# ..        ...                                    ...
# 356   9393332   https://www.airbnb.com/rooms/9393332
# 357   9590078   https://www.airbnb.com/rooms/9590078
# 358   9395165   https://www.airbnb.com/rooms/9395165
# 359   9248616   https://www.airbnb.com/rooms/9248616
# 360   9156574   https://www.airbnb.com/rooms/9156574
#
#                                                  name  \
# 0                  Luxury 1-Bdrm in Downtown Brooklyn
# 1                             Ribeira Charming Duplex
# 2                              ~Ao Lele~ Flying Cloud
# 3                    UWS Brownstone Near Central Park
# ...
